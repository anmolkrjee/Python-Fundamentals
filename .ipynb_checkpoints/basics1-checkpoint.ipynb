# %%
num1 = 50
num2 = 60

add = num1+num2

print("Result : ", add)
# Out:
# Result :  110

# %%
num3 = int(input("Enter a number : "))

num4 = int(input("Enter another number : "))

sub = num4 - num3

print("Result : ", sub)
# Out:
# Enter a number :  100
# Enter another number :  200
# Result :  100

# %%
name = input("Please enter the name: ")
print(type(name))
# Out:
# Please enter the name:  11
# <class 'str'>

# %%
name1 = input("Enter first name : ")
name2 = input("Enter last name : ")

add = name1 + name2

print("Result : ", add)
# Out:
# Enter first name :  Anmol
# Enter last name :  Kumar
# Result :  AnmolKumar

# %%
num1 = int(input("Enter a number : "))
num2 = float(input("Enter another number : "))

add = num1 + num2
print("Result : ", add)
# Out:
# Enter a number :  10
# Enter another number :  10.50
# Result :  20.5

# %%
print(type(print))
# Out:
# <class 'builtin_function_or_method'>
