# %%
 ##Problems without modules

 ##Very large files become difficult to read

 ## Code duplication increses

##modules is simply a python file that contains reusable code.
##It may contain functions, classes, or variables that can be imported and used in other Python files.

##Advantages 

##Organised codes
##Code reusability
##Easier maintenance
