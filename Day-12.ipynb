# %%
##List

##Membership, list alias, repetition, operations, concatenation

##Aggregate functions :- len, sum, max, min, sorted, any, all

##Default :- sorted(list) - Ascending, sorted(list, reverse = True) - Descending

##Methods :- remove(value), pop(index), delete list[index]

##Update :- index, count

##Sort and sorted :- sort is method and sorted built in function
##Reverse and reversed :- method modifies original list wheras built in function cannot

##tuple

# %%
##Practice questions

# %%
##Amazon shopping cart list

cart = ["Laptop", "Mouse", "Keyboard", "Headphones"]

cart.append("Monitor")
print(cart)
cart.remove("Mouse")
print(cart)

print(len(cart))
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Headphones', 'Monitor']
# ['Laptop', 'Keyboard', 'Headphones', 'Monitor']
# 4

# %%
##Airline seat booking list

seat = ["A1", "A2", "A4", "A5", "A6"]
print(seat)
seat.insert(2,"A3")
print(seat)
# Out:
# ['A1', 'A2', 'A4', 'A5', 'A6']
# ['A1', 'A2', 'A3', 'A4', 'A5', 'A6']

# %%
##Food delivery app list

orders = ["Pizza", "Burger", "Biryani", "Thali", "Special thali", "Paneer bhurji"]
print(orders)
orders.pop()
print(orders)
# Out:
# ['Pizza', 'Burger', 'Biryani', 'Thali', 'Special thali', 'Paneer bhurji']
# ['Pizza', 'Burger', 'Biryani', 'Thali', 'Special thali']

# %%
##Warehouse inventory list

inventory_list = ["Laptop", "Mouse", "Keyboard", "Monitor", "Printer", "Hard Disk", "Pen drive"]
print(inventory_list)
inventory_list.sort()
print(inventory_list)
inventory_list.reverse()
print(inventory_list)
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Printer', 'Hard Disk', 'Pen drive']
# ['Hard Disk', 'Keyboard', 'Laptop', 'Monitor', 'Mouse', 'Pen drive', 'Printer']
# ['Printer', 'Pen drive', 'Mouse', 'Monitor', 'Laptop', 'Keyboard', 'Hard Disk']

# %%
##Student Database Backup list

database = ["Anmol", "Aman", "Nitish", "Priya","Anshu", "Manoj"]
print(database)
a = database.copy()
print(a)
a.insert(2, "Rahu1")
print(a)
# Out:
# ['Anmol', 'Aman', 'Nitish', 'Priya', 'Anshu', 'Manoj']
# ['Anmol', 'Aman', 'Nitish', 'Priya', 'Anshu', 'Manoj']
# ['Anmol', 'Aman', 'Rahu1', 'Nitish', 'Priya', 'Anshu', 'Manoj']

# %%
##HR Contact Directory list

contact = ["Anmol", "Aman", "Nitish", "Priya","Anshu", "Manoj", "Aman", "Aman", "Rahul"]
print(contact.index("Aman"))
print(contact.count("Aman"))
print(contact.count("Rahul"))
# Out:
# 1
# 3
# 1

# %%
##Emergency Alert System list

# Emergency Alert System list

emergency = [
    "Police",
    "Fire Department",
    "Ambulance",
    "Disaster Management",
    "Poison Control",
    "Emergency Shelter"
]

print(emergency.clear())
# Out:
# None

# %%
##Spotify Playlist list

## Spotify Playlist list
playlist1 = [
    "Today's Top Hits",
    "RapCaviar",
    "Rock Classics",
    "Chill Hits",
    "Lofi Beats",
    "Pop Rising",
    "All Out 2010s"
]
print(playlist1)
playlist1.extend( ["Peaceful Piano","Mint", "Jazz Vibes"])
print(playlist1)
# Out:
# ["Today's Top Hits", 'RapCaviar', 'Rock Classics', 'Chill Hits', 'Lofi Beats', 'Pop Rising', 'All Out 2010s']
# ["Today's Top Hits", 'RapCaviar', 'Rock Classics', 'Chill Hits', 'Lofi Beats', 'Pop Rising', 'All Out 2010s', 'Peaceful Piano', 'Mint', 'Jazz Vibes']

# %%
a = [10, 20]
b = a
b.append(30)
print(a)
# Out:
# [10, 20, 30]

# %%
a = [10, 20]
b = a.copy()
b.append(30)
print(a)
# Out:
# [10, 20]

# %%
##Mini Project

##Library mangement system :- Store books and add books, search issue, return, create backup, store books 
## and display final library using appropriate list methods

# %%
# Mini Project: Library Management System

# Initial library
library = [
    "Python Basics",
    "Data Structures",
    "Machine Learning",
    "Artificial Intelligence",
    "Web Development"
]

issued_books = []

while True:
    print("\n====== Library Management System ======")
    print("1. Display Books")
    print("2. Add Book")
    print("3. Search Book")
    print("4. Issue Book")
    print("5. Return Book")
    print("6. Create Backup")
    print("7. Sort Books")
    print("8. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        print("\nAvailable Books:")
        for book in library:
            print("-", book)

    elif choice == "2":
        book = input("Enter book name: ")
        library.append(book)
        print("Book added successfully.")

    elif choice == "3":
        book = input("Enter book name to search: ")
        if book in library:
            print("Book is available.")
        else:
            print("Book not found.")

    elif choice == "4":
        book = input("Enter book name to issue: ")
        if book in library:
            library.remove(book)
            issued_books.append(book)
            print("Book issued successfully.")
        else:
            print("Book not available.")

    elif choice == "5":
        book = input("Enter book name to return: ")
        if book in issued_books:
            issued_books.remove(book)
            library.append(book)
            print("Book returned successfully.")
        else:
            print("This book was not issued.")

    elif choice == "6":
        backup = library.copy()
        print("Library backup created.")
        print("Backup:", backup)

    elif choice == "7":
        library.sort()
        print("Books sorted successfully.")

    elif choice == "8":
        print("\nFinal Library:")
        for book in library:
            print("-", book)

        print("\nIssued Books:")
        for book in issued_books:
            print("-", book)

        print("\nThank you for using the Library Management System!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# ====== Library Management System ======
# 1. Display Books
# 2. Add Book
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Create Backup
# 7. Sort Books
# 8. Exit
# Enter your choice:  1
# Available Books:
# - Python Basics
# - Data Structures
# - Machine Learning
# - Artificial Intelligence
# - Web Development
#
# ====== Library Management System ======
# 1. Display Books
# 2. Add Book
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Create Backup
# 7. Sort Books
# 8. Exit
# Enter your choice:  1
# Available Books:
# - Python Basics
# - Data Structures
# - Machine Learning
# - Artificial Intelligence
# - Web Development
#
# ====== Library Management System ======
# 1. Display Books
# 2. Add Book
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Create Backup
# 7. Sort Books
# 8. Exit
# Enter your choice:  2
# Enter book name:  DSA
# Book added successfully.
#
# ====== Library Management System ======
# 1. Display Books
# 2. Add Book
# 3. Search Book
# 4. Issue Book
# ...
