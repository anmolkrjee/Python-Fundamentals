# %%
##. Practice questions:- 

##1 one loop is inside another loop, which is also inside a third loop

##2. one , loop, loop

##3. inner loop

##4. outer loop

##5. True

##6. False

##7. State

##8. 3

##9. 5

##10. Building -> Floor -> Room,  Country -> State -> City,  

##11. 
    000
    001
    010
    011
    100
    101
    110
    111

##12.  34454556

##13. 
    **
    **
    **
    **

##14.

    Layer 0
    Row 0
    0 1 2
    Row 1
    0 1 2
    Layer 1
    Row 0
    0 1 2
    Row 1
    0 1 2

##15.  12


##16. 
    001
    011
    101
    111

##17.

    000
    002
    010
    012
    100
    102
    110
    112
        
        
##19.
    1
    2
    2
    4
    3
    6

##20.

    1- room 
    2- building
    3- 12
    4- 12

##18. Outer -> , Middle -> 6, Inner -> 24

# %%
##Dry run and debug

##1. 
    000
    001
    010
    011
    100
    101
    110
    111

##2.

    001
    011
    101
    111

##3.
